# %%
import pandas as pd

df = pd.read_csv("./data/Application/df_battery_leistung.csv", sep=',')

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("./data/Application/df_app_data.csv", sep=',')
df.head()
# Out:
#   batteryname_  amperestunden  zyklus_                        comment_ type_  \
# 0          RW1       2.094997        0  low current discharge at 0.04A     D
# 1          RW1      -2.120549        1              low current charge     C
# 2          RW1      -0.021099        2                reference charge     C
# 3          RW1       2.000364        3             reference discharge     D
# 4          RW1      -2.005160        4                reference charge     C
#
#    temperature_amax  temperature_amin  temperature_mean  time_amin  \
# 0          18.79972          17.08313         17.939268    1538.07
# 1          18.64223          17.06738         17.867832  190514.75
# 2          18.37451          18.09103         18.232178  381786.29
# 3          23.56742          18.39025         21.798768  385232.92
# 4          25.28264          17.69732         20.055134  392434.74
#
#    time_entladen_stark_vorher  time_entladen_leicht_vorher  \
# ...
