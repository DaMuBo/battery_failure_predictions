# %% [markdown]
# ## Erstmal auf den Zyklus gruppieren und dann Features erstellen
#
# offen:
# - kommentierung

# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np

import os
import sys
import logging

import functions as fu
from feature_engineering import *

# Pfade setzen
c_fold = fu.get_folder()
p_fold = c_fold + '\data\Prepared'
folder = c_fold + '\data\Processed\Zyklus'
folder_final = c_fold + '\data\Processed\\final'


# Initialize Logging
logging.basicConfig(format='[%(asctime)s] %(levelname)s: %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.INFO,
                    handlers=[
                        logging.FileHandler(
                            filename='datalogger.log',
                            mode='a',
                            encoding='utf-8'),
                        logging.StreamHandler(sys.stdout)])

# %%
def stark_leicht(type_, current_mean, relativeTime_amax):
    entladen_stark = 0
    entladen_leicht = 0
    laden_stark = 0
    laden_leicht = 0
    pause = 0
    
    
    if type_ == 'D': #discharge
        if current_mean >= 3:
            entladen_stark = relativeTime_amax
        else:
            entladen_leicht = relativeTime_amax
    if type_ == 'C': #charge
        if current_mean <= -3:
            laden_stark = relativeTime_amax
        else:
            laden_leicht = relativeTime_amax
    if type_ == 'R':
        pause = relativeTime_amax
    return entladen_stark, entladen_leicht, laden_stark, laden_leicht, pause

    

def temp_hoch(temperature_amax, relativeTime_amax):
    temp_hoch = 0
    if temperature_amax >= 30:
        return relativeTime_amax
    else:
        return 0
        

for file in os.listdir(p_fold):
    if ".csv" in file:
# file = "prepared_RW1.csv" #für tests nur eins
        logging.info(f"<<< Started processing file: {file} >>>")
        new_filename = file.replace("prepared","processed")

        df = pd.read_csv(f"{p_fold}\\{file}", index_col = 0,
                                 #nrows= 100000
                                )
        logging.info(f"<<< Size of Dataframe: {df.shape} >>>")

        #Auf Ebene Batterie + Zyklus gruppieren mit benötigten Aggregationen
        df_pv = pd.pivot_table(
           df,
           index=['batteryname','zyklus','comment','type'],
           aggfunc={'time': np.min, 'relativeTime':  np.max, 'voltage': [np.min, np.max, np.mean], 'current': [np.min, np.max, np.mean], 'temperature': [np.min, np.max, np.mean]}
        ).reset_index()

        df_pv.columns = ['_'.join(col) for col in list(df_pv.columns)]



        df_pv['time_entladen_stark'],df_pv['time_entladen_leicht'],df_pv['time_laden_stark'],df_pv['time_laden_leicht'],df_pv['time_pause']  = zip(*df_pv.apply(lambda x: stark_leicht(x['type_'],x['current_mean'],x['relativeTime_amax']),axis=1))

        df_pv['time_entladen_stark_vorher'] = df_pv.time_entladen_stark.cumsum()
        df_pv['time_entladen_leicht_vorher'] = df_pv.time_entladen_leicht.cumsum()
        df_pv['time_laden_stark_vorher'] = df_pv.time_laden_stark.cumsum()
        df_pv['time_laden_stark_vorher'] = df_pv.time_laden_leicht.cumsum()
        df_pv['time_pause_vorher'] = df_pv.time_pause.cumsum()


        df_pv['time_temp_hoch'] = df_pv.apply(lambda x: temp_hoch(x['temperature_amax'],x['relativeTime_amax']),axis=1)

        df_pv['time_temp_hoch_vorher'] = df_pv.time_temp_hoch.cumsum()

        df_pv['amperestunden'] = (df_pv['current_mean']*df_pv['relativeTime_amax'])/3600
        #mapply(trapz,refDisSteps$relativeTime,refDisSteps$current)/3600

        df_pv_filtered = df_pv[df_pv['comment_'] == 'reference discharge']


        logging.info(f"<<< Start saving dataframe with shape {df_pv_filtered.shape} >>>")
        df_pv.to_csv(f"{folder}\\{new_filename}", sep=',', index=False)
        logging.info(f"<<< Saved processed file in directory {folder}\\{new_filename} >>>")
# Out:
# [21:09:07] INFO: <<< Started processing file: prepared_RW1.csv >>>
# [21:09:12] INFO: <<< Size of Dataframe: (2958840, 11) >>>
# [21:09:13] INFO: <<< Start saving dataframe with shape (48, 27) >>>
# [21:09:13] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW1.csv >>>
# [21:09:13] INFO: <<< Started processing file: prepared_RW10.csv >>>
# [21:09:28] INFO: <<< Size of Dataframe: (8596025, 11) >>>
# [21:09:34] INFO: <<< Start saving dataframe with shape (77, 27) >>>
# [21:09:37] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW10.csv >>>
# [21:09:37] INFO: <<< Started processing file: prepared_RW11.csv >>>
# [21:09:53] INFO: <<< Size of Dataframe: (8664510, 11) >>>
# [21:09:59] INFO: <<< Start saving dataframe with shape (77, 27) >>>
# [21:10:01] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW11.csv >>>
# [21:10:01] INFO: <<< Started processing file: prepared_RW12.csv >>>
# [21:10:17] INFO: <<< Size of Dataframe: (8638882, 11) >>>
# [21:10:24] INFO: <<< Start saving dataframe with shape (76, 27) >>>
# [21:10:27] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW12.csv >>>
# [21:10:27] INFO: <<< Started processing file: prepared_RW13.csv >>>
# [21:10:31] INFO: <<< Size of Dataframe: (2058466, 11) >>>
# [21:10:33] INFO: <<< Start saving dataframe with shape (23, 27) >>>
# [21:10:35] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW13.csv >>>
# [21:10:35] INFO: <<< Started processing file: prepared_RW14.csv >>>
# [21:10:38] INFO: <<< Size of Dataframe: (1731073, 11) >>>
# [21:10:40] INFO: <<< Start saving dataframe with shape (24, 27) >>>
# [21:10:41] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW14.csv >>>
# [21:10:41] INFO: <<< Started processing file: prepared_RW15.csv >>>
# [21:10:44] INFO: <<< Size of Dataframe: (1790880, 11) >>>
# [21:10:46] INFO: <<< Start saving dataframe with shape (24, 27) >>>
# [21:10:47] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW15.csv >>>
# [21:10:47] INFO: <<< Started processing file: prepared_RW16.csv >>>
# [21:10:50] INFO: <<< Size of Dataframe: (1563555, 11) >>>
# [21:10:52] INFO: <<< Start saving dataframe with shape (19, 27) >>>
# [21:10:53] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW16.csv >>>
# [21:10:53] INFO: <<< Started processing file: prepared_RW17.csv >>>
# [21:10:56] INFO: <<< Size of Dataframe: (1276444, 11) >>>
# [21:10:58] INFO: <<< Start saving dataframe with shape (29, 27) >>>
# [21:10:59] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW17.csv >>>
# [21:10:59] INFO: <<< Started processing file: prepared_RW18.csv >>>
# [21:11:02] INFO: <<< Size of Dataframe: (1298508, 11) >>>
# [21:11:04] INFO: <<< Start saving dataframe with shape (28, 27) >>>
# [21:11:04] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW18.csv >>>
# [21:11:04] INFO: <<< Started processing file: prepared_RW19.csv >>>
# [21:11:07] INFO: <<< Size of Dataframe: (1350773, 11) >>>
# [21:11:09] INFO: <<< Start saving dataframe with shape (27, 27) >>>
# [21:11:09] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW19.csv >>>
# [21:11:09] INFO: <<< Started processing file: prepared_RW2.csv >>>
# [21:11:15] INFO: <<< Size of Dataframe: (2895644, 11) >>>
# [21:11:17] INFO: <<< Start saving dataframe with shape (52, 27) >>>
# [21:11:17] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW2.csv >>>
# [21:11:17] INFO: <<< Started processing file: prepared_RW20.csv >>>
# [21:11:19] INFO: <<< Size of Dataframe: (1222375, 11) >>>
# [21:11:21] INFO: <<< Start saving dataframe with shape (29, 27) >>>
# [21:11:21] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW20.csv >>>
# [21:11:21] INFO: <<< Started processing file: prepared_RW21.csv >>>
# [21:11:24] INFO: <<< Size of Dataframe: (1494692, 11) >>>
# [21:11:26] INFO: <<< Start saving dataframe with shape (11, 27) >>>
# [21:11:27] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW21.csv >>>
# [21:11:27] INFO: <<< Started processing file: prepared_RW22.csv >>>
# [21:11:30] INFO: <<< Size of Dataframe: (1389063, 11) >>>
# [21:11:31] INFO: <<< Start saving dataframe with shape (10, 27) >>>
# [21:11:32] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW22.csv >>>
# [21:11:32] INFO: <<< Started processing file: prepared_RW23.csv >>>
# [21:11:35] INFO: <<< Size of Dataframe: (1463058, 11) >>>
# [21:11:37] INFO: <<< Start saving dataframe with shape (11, 27) >>>
# [21:11:38] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW23.csv >>>
# [21:11:38] INFO: <<< Started processing file: prepared_RW24.csv >>>
# [21:11:41] INFO: <<< Size of Dataframe: (1421691, 11) >>>
# [21:11:42] INFO: <<< Start saving dataframe with shape (11, 27) >>>
# [21:11:43] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW24.csv >>>
# [21:11:43] INFO: <<< Started processing file: prepared_RW25.csv >>>
# [21:11:44] INFO: <<< Size of Dataframe: (806283, 11) >>>
# [21:11:45] INFO: <<< Start saving dataframe with shape (13, 27) >>>
# [21:11:45] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW25.csv >>>
# [21:11:45] INFO: <<< Started processing file: prepared_RW26.csv >>>
# [21:11:46] INFO: <<< Size of Dataframe: (697936, 11) >>>
# [21:11:47] INFO: <<< Start saving dataframe with shape (14, 27) >>>
# [21:11:47] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW26.csv >>>
# [21:11:47] INFO: <<< Started processing file: prepared_RW27.csv >>>
# [21:11:49] INFO: <<< Size of Dataframe: (905559, 11) >>>
# [21:11:50] INFO: <<< Start saving dataframe with shape (12, 27) >>>
# [21:11:50] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW27.csv >>>
# [21:11:50] INFO: <<< Started processing file: prepared_RW28.csv >>>
# [21:11:51] INFO: <<< Size of Dataframe: (826968, 11) >>>
# [21:11:52] INFO: <<< Start saving dataframe with shape (12, 27) >>>
# [21:11:53] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW28.csv >>>
# [21:11:53] INFO: <<< Started processing file: prepared_RW3.csv >>>
# [21:12:00] INFO: <<< Size of Dataframe: (3005994, 11) >>>
# [21:12:01] INFO: <<< Start saving dataframe with shape (44, 27) >>>
# [21:12:01] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW3.csv >>>
# [21:12:01] INFO: <<< Started processing file: prepared_RW4.csv >>>
# [21:12:06] INFO: <<< Size of Dataframe: (2752836, 11) >>>
# [21:12:08] INFO: <<< Start saving dataframe with shape (38, 27) >>>
# [21:12:08] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW4.csv >>>
# [21:12:08] INFO: <<< Started processing file: prepared_RW5.csv >>>
# [21:12:13] INFO: <<< Size of Dataframe: (2857789, 11) >>>
# [21:12:14] INFO: <<< Start saving dataframe with shape (42, 27) >>>
# [21:12:14] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW5.csv >>>
# [21:12:14] INFO: <<< Started processing file: prepared_RW6.csv >>>
# [21:12:17] INFO: <<< Size of Dataframe: (1755264, 11) >>>
# [21:12:18] INFO: <<< Start saving dataframe with shape (22, 27) >>>
# [21:12:18] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW6.csv >>>
# [21:12:18] INFO: <<< Started processing file: prepared_RW7.csv >>>
# [21:12:24] INFO: <<< Size of Dataframe: (2944002, 11) >>>
# [21:12:25] INFO: <<< Start saving dataframe with shape (49, 27) >>>
# [21:12:26] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW7.csv >>>
# [21:12:26] INFO: <<< Started processing file: prepared_RW8.csv >>>
# [21:12:32] INFO: <<< Size of Dataframe: (2801637, 11) >>>
# [21:12:33] INFO: <<< Start saving dataframe with shape (48, 27) >>>
# [21:12:33] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW8.csv >>>
# [21:12:33] INFO: <<< Started processing file: prepared_RW9.csv >>>
# [21:12:52] INFO: <<< Size of Dataframe: (8532073, 11) >>>
# [21:12:57] INFO: <<< Start saving dataframe with shape (80, 27) >>>
# [21:12:59] INFO: <<< Saved processed file in directory C:\Users\danie\OneDrive\Dokumente\_Programmierung\python_workspaces\Uni_Master\battery_failure_predictions\data\Processed\Zyklus\processed_RW9.csv >>>

# %% [markdown]
# ## DFs zusammenführen

# %%
d = []

df_full = pd.DataFrame(d, columns=df_pv_filtered.columns)

for file in os.listdir(folder):
    if ".csv" in file:
        df = pd.read_csv(f"{folder}\\{file}")
        df_full = df_full.append(df)
df_full = df_full.reset_index()

# %% [markdown]
# # Variablenauswahl
# * **index** - kann raus
# * **batteryname_** - kann weg: keinen Einfluss
# * **zyklus_** - bleibt: Anzahl an Lade/Entlade/Pause Wechseln
# * **comment_** - kann weg: ist in time_entladen_*
# * **type_** - kann weg: ist in time_entladen_*
# * **current_amax** - kann weg: ist in Zielvariable/immer gleich
# * **current_amin** - kann weg: ist in Zielvariable/immer gleich
# * **current_mean** - kann weg: ist in Zielvariable/immer gleich
# * **relativeTime_amax** - kann weg: ist in Zielvariable
# * **temperature_amax** - bleibt: kann man mal ausprobieren, ob Temp Einfluss hat
# * **temperature_amin** - bleibt: kann man mal ausprobieren, ob Temp Einfluss hat
# * **temperature_mean** - bleibt: kann man mal ausprobieren, ob Temp Einfluss hat
# * **time_amin** - bleibt: Gesamtalter der Batterie bei Start
# * **voltage_amax** - kann weg: bei Ref Discharge immer von 4.2V zu 3.2V
# * **voltage_amin** - kann weg: bei Ref Discharge immer von 4.2V zu 3.2V
# * **voltage_mean** - kann weg: bei Ref Discharge immer von 4.2V zu 3.2V
# * **time_entladen_stark** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_entladen_leicht** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_laden_stark** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_laden_leicht** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_pause** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_entladen_stark_vorher** - bleibt: wie vorher verwendet
# * **time_entladen_leicht_vorher** - bleibt: wie vorher verwendet
# * **time_laden_stark_vorher** - bleibt: wie vorher verwendet
# * **time_pause_vorher** - bleibt: wie vorher verwendet
# * **time_temp_hoch** - bleibt: wie vorher verwendet
# * **time_temp_hoch_vorher** - bleibt: wie vorher verwendet
# * **amperestunden** - bleibt: Zielvariable

# %%
var_auswahl = [
    "batteryname_",
    "amperestunden",
    "zyklus_",
    "comment_",
    "type_",
    "temperature_amax",
    "temperature_amin",
    "temperature_mean",
    "time_amin",
    "time_entladen_stark_vorher",
    "time_entladen_leicht_vorher",
    "time_laden_stark_vorher",
    "time_pause_vorher",
    "time_temp_hoch",
    "time_temp_hoch_vorher"
]

df_final = df_full[var_auswahl]
df_final.to_csv(f"{folder_final}\\df_fertige_features.csv", sep=',', index=False)
df_final
# Out:
#         batteryname_  amperestunden zyklus_                        comment_  \
# 0                RW1       2.094997       0  low current discharge at 0.04A
# 1                RW1      -2.120549       1              low current charge
# 2                RW1      -0.021099       2                reference charge
# 3                RW1       2.000364       3             reference discharge
# 4                RW1      -2.005160       4                reference charge
# ...              ...            ...     ...                             ...
# 1117889          RW9       0.000000  113573   rest post reference discharge
# 1117890          RW9      -0.774939  113574                reference charge
# 1117891          RW9       0.000000  113575      rest post reference charge
# 1117892          RW9       0.750203  113576             reference discharge
# 1117893          RW9       0.000000  113577   rest post reference discharge
#
#         type_  temperature_amax  temperature_amin  temperature_mean  \
# 0           D          18.79972          17.08313         17.939268
# 1           C          18.64223          17.06738         17.867832
# 2           C          18.37451          18.09103         18.232178
# 3           D          23.56742          18.39025         21.798768
# 4           C          25.28264          17.69732         20.055134
# ...       ...               ...               ...               ...
# 1117889     R          38.29132          30.73195         32.874813
# 1117890     C          34.13290          30.76287         32.242548
# 1117891     R          32.47880          32.40151         32.446385
# 1117892     D          38.86329          32.46334         35.958514
# 1117893     R          38.86329          32.15417         33.766021
#
#            time_amin  time_entladen_stark_vorher  time_entladen_leicht_vorher  \
# 0            1538.07                        0.00                    188976.68
# 1          190514.75                        0.00                    188976.68
# 2          381786.29                        0.00                    188976.68
# 3          385232.92                        0.00                    196178.50
# 4          392434.74                        0.00                    196178.50
# ...              ...                         ...                          ...
# 1117889  12675446.09                   319549.85                   4142731.52
# 1117890  12682646.12                   319549.85                   4142731.52
# 1117891  12703178.80                   319549.85                   4142731.52
# 1117892  12703478.83                   319549.85                   4145432.36
# 1117893  12706179.64                   319549.85                   4145432.36
#
#          time_laden_stark_vorher  time_pause_vorher  time_temp_hoch  \
# 0                           0.00               0.00            0.00
# 1                      191271.64               0.00            0.00
# 2                      194718.28               0.00            0.00
# 3                      194718.28               0.00            0.00
# 4                      207816.73               0.00            0.00
# ...                          ...                ...             ...
# 1117889               5144349.95         1101476.63         7200.00
# 1117890               5164882.66         1101476.63        20532.71
# 1117891               5164882.66         1101776.63          300.00
# 1117892               5164882.66         1101776.63         2700.84
# 1117893               5164882.66         1108976.63         7200.00
#
#          time_temp_hoch_vorher
# 0                 0.000000e+00
# 1                 0.000000e+00
# 2                 0.000000e+00
# 3                 0.000000e+00
# 4                 0.000000e+00
# ...                        ...
# 1117889           9.401590e+06
# 1117890           9.422123e+06
# 1117891           9.422423e+06
# 1117892           9.425124e+06
# 1117893           9.432324e+06
#
# [1117894 rows x 15 columns]

# %% [markdown]
# ## Nachher:
# * Bei Temperatur scheint es Ausreißer in die -4000er Region zu geben, muss man noch ersetzen wenn man es benutzen will
