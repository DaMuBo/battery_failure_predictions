# %% [markdown]
# ## Erstmal auf den Zyklus gruppieren und dann Features erstellen
#
# offen:
# - kommentierung

# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np

import os
import sys
import logging

parentdir = os.path.dirname(os.path.abspath(''))
sys.path.append(parentdir)

import functions as fu
from feature_engineering import *

# Pfade setzen
c_fold = fu.get_folder()
p_fold = c_fold + '\data\Prepared'
folder = c_fold + '\data\Processed\Zyklus'
folder_final = c_fold + '\data\Processed\\final'


# Initialize Logging
logging.basicConfig(format='[%(asctime)s] %(levelname)s: %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.INFO,
                    handlers=[
                        logging.FileHandler(
                            filename='datalogger.log',
                            mode='a',
                            encoding='utf-8'),
                        logging.StreamHandler(sys.stdout)])

# %%
def stark_leicht(type_, current_mean, relativeTime_amax):
    entladen_stark = 0
    entladen_leicht = 0
    laden_stark = 0
    laden_leicht = 0
    pause = 0
    
    
    if type_ == 'D': #discharge
        if current_mean >= 3:
            entladen_stark = relativeTime_amax
        else:
            entladen_leicht = relativeTime_amax
    if type_ == 'C': #charge
        if current_mean <= -3:
            laden_stark = relativeTime_amax
        else:
            laden_leicht = relativeTime_amax
    if type_ == 'R':
        pause = relativeTime_amax
    return entladen_stark, entladen_leicht, laden_stark, laden_leicht, pause

    

def temp_hoch(temperature_amax, relativeTime_amax):
    temp_hoch = 0
    if temperature_amax >= 30:
        return relativeTime_amax
    else:
        return 0
        

for file in os.listdir(p_fold):
    if ".csv" in file:
# file = "prepared_RW1.csv" #für tests nur eins
        logging.info(f"<<< Started processing file: {file} >>>")
        new_filename = file.replace("prepared","processed")

        df = pd.read_csv(f"{p_fold}\\{file}", index_col = 0,
                                 #nrows= 100000
                                )
        logging.info(f"<<< Size of Dataframe: {df.shape} >>>")

        #Auf Ebene Batterie + Zyklus gruppieren mit benötigten Aggregationen
        df_pv = pd.pivot_table(
           df,
           index=['batteryname','zyklus','comment','type'],
           aggfunc={'time': np.min, 'relativeTime':  np.max, 'voltage': [np.min, np.max, np.mean], 'current': [np.min, np.max, np.mean], 'temperature': [np.min, np.max, np.mean]}
        ).reset_index()

        df_pv.columns = ['_'.join(col) for col in list(df_pv.columns)]



        df_pv['time_entladen_stark'],df_pv['time_entladen_leicht'],df_pv['time_laden_stark'],df_pv['time_laden_leicht'],df_pv['time_pause']  = zip(*df_pv.apply(lambda x: stark_leicht(x['type_'],x['current_mean'],x['relativeTime_amax']),axis=1))

        df_pv['time_entladen_stark_vorher'] = df_pv.time_entladen_stark.cumsum()
        df_pv['time_entladen_leicht_vorher'] = df_pv.time_entladen_leicht.cumsum()
        df_pv['time_laden_stark_vorher'] = df_pv.time_laden_stark.cumsum()
        df_pv['time_laden_leicht_vorher'] = df_pv.time_laden_leicht.cumsum()
        df_pv['time_pause_vorher'] = df_pv.time_pause.cumsum()


        df_pv['time_temp_hoch'] = df_pv.apply(lambda x: temp_hoch(x['temperature_amax'],x['relativeTime_amax']),axis=1)

        df_pv['time_temp_hoch_vorher'] = df_pv.time_temp_hoch.cumsum()

        df_pv['amperestunden'] = (df_pv['current_mean']*df_pv['relativeTime_amax'])/3600
        #mapply(trapz,refDisSteps$relativeTime,refDisSteps$current)/3600


        logging.info(f"<<< Start saving dataframe with shape {df_pv.shape} >>>")
        df_pv.to_csv(f"{folder}\\{new_filename}", sep=',', index=False)
        logging.info(f"<<< Saved processed file in directory {folder}\\{new_filename} >>>")
# Out:
# [19:55:30] INFO: <<< Started processing file: prepared_RW1.csv >>>
# [19:55:35] INFO: <<< Size of Dataframe: (2958840, 11) >>>
# [19:55:36] INFO: <<< Start saving dataframe with shape (17065, 28) >>>
# [19:55:36] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW1.csv >>>
# [19:55:36] INFO: <<< Started processing file: prepared_RW10.csv >>>
# [19:55:49] INFO: <<< Size of Dataframe: (8596025, 11) >>>
# [19:55:55] INFO: <<< Start saving dataframe with shape (110818, 28) >>>
# [19:55:57] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW10.csv >>>
# [19:55:57] INFO: <<< Started processing file: prepared_RW11.csv >>>
# [19:56:10] INFO: <<< Size of Dataframe: (8664510, 11) >>>
# [19:56:16] INFO: <<< Start saving dataframe with shape (109389, 28) >>>
# [19:56:18] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW11.csv >>>
# [19:56:18] INFO: <<< Started processing file: prepared_RW12.csv >>>
# [19:56:31] INFO: <<< Size of Dataframe: (8638882, 11) >>>
# [19:56:37] INFO: <<< Start saving dataframe with shape (110013, 28) >>>
# [19:56:39] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW12.csv >>>
# [19:56:39] INFO: <<< Started processing file: prepared_RW13.csv >>>
# [19:56:43] INFO: <<< Size of Dataframe: (2058466, 11) >>>
# [19:56:45] INFO: <<< Start saving dataframe with shape (56049, 28) >>>
# [19:56:46] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW13.csv >>>
# [19:56:46] INFO: <<< Started processing file: prepared_RW14.csv >>>
# [19:56:49] INFO: <<< Size of Dataframe: (1731073, 11) >>>
# [19:56:51] INFO: <<< Start saving dataframe with shape (45868, 28) >>>
# [19:56:51] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW14.csv >>>
# [19:56:51] INFO: <<< Started processing file: prepared_RW15.csv >>>
# [19:56:54] INFO: <<< Size of Dataframe: (1790880, 11) >>>
# [19:56:56] INFO: <<< Start saving dataframe with shape (47720, 28) >>>
# [19:56:57] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW15.csv >>>
# [19:56:57] INFO: <<< Started processing file: prepared_RW16.csv >>>
# [19:57:00] INFO: <<< Size of Dataframe: (1563555, 11) >>>
# [19:57:01] INFO: <<< Start saving dataframe with shape (42366, 28) >>>
# [19:57:02] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW16.csv >>>
# [19:57:02] INFO: <<< Started processing file: prepared_RW17.csv >>>
# [19:57:04] INFO: <<< Size of Dataframe: (1276444, 11) >>>
# [19:57:05] INFO: <<< Start saving dataframe with shape (30912, 28) >>>
# [19:57:06] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW17.csv >>>
# [19:57:06] INFO: <<< Started processing file: prepared_RW18.csv >>>
# [19:57:08] INFO: <<< Size of Dataframe: (1298508, 11) >>>
# [19:57:09] INFO: <<< Start saving dataframe with shape (31877, 28) >>>
# [19:57:10] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW18.csv >>>
# [19:57:10] INFO: <<< Started processing file: prepared_RW19.csv >>>
# [19:57:12] INFO: <<< Size of Dataframe: (1350773, 11) >>>
# [19:57:14] INFO: <<< Start saving dataframe with shape (33877, 28) >>>
# [19:57:14] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW19.csv >>>
# [19:57:14] INFO: <<< Started processing file: prepared_RW2.csv >>>
# [19:57:19] INFO: <<< Size of Dataframe: (2895644, 11) >>>
# [19:57:20] INFO: <<< Start saving dataframe with shape (16987, 28) >>>
# [19:57:20] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW2.csv >>>
# [19:57:20] INFO: <<< Started processing file: prepared_RW20.csv >>>
# [19:57:23] INFO: <<< Size of Dataframe: (1222375, 11) >>>
# [19:57:24] INFO: <<< Start saving dataframe with shape (29018, 28) >>>
# [19:57:24] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW20.csv >>>
# [19:57:24] INFO: <<< Started processing file: prepared_RW21.csv >>>
# [19:57:27] INFO: <<< Size of Dataframe: (1494692, 11) >>>
# [19:57:29] INFO: <<< Start saving dataframe with shape (42700, 28) >>>
# [19:57:30] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW21.csv >>>
# [19:57:30] INFO: <<< Started processing file: prepared_RW22.csv >>>
# [19:57:32] INFO: <<< Size of Dataframe: (1389063, 11) >>>
# [19:57:34] INFO: <<< Start saving dataframe with shape (39540, 28) >>>
# [19:57:34] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW22.csv >>>
# [19:57:34] INFO: <<< Started processing file: prepared_RW23.csv >>>
# [19:57:36] INFO: <<< Size of Dataframe: (1463058, 11) >>>
# [19:57:38] INFO: <<< Start saving dataframe with shape (41694, 28) >>>
# [19:57:39] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW23.csv >>>
# [19:57:39] INFO: <<< Started processing file: prepared_RW24.csv >>>
# [19:57:41] INFO: <<< Size of Dataframe: (1421691, 11) >>>
# [19:57:43] INFO: <<< Start saving dataframe with shape (40384, 28) >>>
# [19:57:44] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW24.csv >>>
# [19:57:44] INFO: <<< Started processing file: prepared_RW25.csv >>>
# [19:57:45] INFO: <<< Size of Dataframe: (806283, 11) >>>
# [19:57:46] INFO: <<< Start saving dataframe with shape (20508, 28) >>>
# [19:57:46] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW25.csv >>>
# [19:57:46] INFO: <<< Started processing file: prepared_RW26.csv >>>
# [19:57:47] INFO: <<< Size of Dataframe: (697936, 11) >>>
# [19:57:48] INFO: <<< Start saving dataframe with shape (16666, 28) >>>
# [19:57:48] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW26.csv >>>
# [19:57:48] INFO: <<< Started processing file: prepared_RW27.csv >>>
# [19:57:49] INFO: <<< Size of Dataframe: (905559, 11) >>>
# [19:57:50] INFO: <<< Start saving dataframe with shape (23659, 28) >>>
# [19:57:50] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW27.csv >>>
# [19:57:50] INFO: <<< Started processing file: prepared_RW28.csv >>>
# [19:57:51] INFO: <<< Size of Dataframe: (826968, 11) >>>
# [19:57:52] INFO: <<< Start saving dataframe with shape (21121, 28) >>>
# [19:57:53] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW28.csv >>>
# [19:57:53] INFO: <<< Started processing file: prepared_RW3.csv >>>
# [19:57:58] INFO: <<< Size of Dataframe: (3005994, 11) >>>
# [19:57:59] INFO: <<< Start saving dataframe with shape (12826, 28) >>>
# [19:57:59] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW3.csv >>>
# [19:57:59] INFO: <<< Started processing file: prepared_RW4.csv >>>
# [19:58:03] INFO: <<< Size of Dataframe: (2752836, 11) >>>
# [19:58:04] INFO: <<< Start saving dataframe with shape (10953, 28) >>>
# [19:58:05] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW4.csv >>>
# [19:58:05] INFO: <<< Started processing file: prepared_RW5.csv >>>
# [19:58:09] INFO: <<< Size of Dataframe: (2857789, 11) >>>
# [19:58:10] INFO: <<< Start saving dataframe with shape (11616, 28) >>>
# [19:58:10] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW5.csv >>>
# [19:58:10] INFO: <<< Started processing file: prepared_RW6.csv >>>
# [19:58:13] INFO: <<< Size of Dataframe: (1755264, 11) >>>
# [19:58:14] INFO: <<< Start saving dataframe with shape (7111, 28) >>>
# [19:58:14] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW6.csv >>>
# [19:58:14] INFO: <<< Started processing file: prepared_RW7.csv >>>
# [19:58:19] INFO: <<< Size of Dataframe: (2944002, 11) >>>
# [19:58:21] INFO: <<< Start saving dataframe with shape (17277, 28) >>>
# [19:58:21] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW7.csv >>>
# [19:58:21] INFO: <<< Started processing file: prepared_RW8.csv >>>
# [19:58:26] INFO: <<< Size of Dataframe: (2801637, 11) >>>
# [19:58:27] INFO: <<< Start saving dataframe with shape (16302, 28) >>>
# [19:58:27] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW8.csv >>>
# [19:58:27] INFO: <<< Started processing file: prepared_RW9.csv >>>
# [19:58:43] INFO: <<< Size of Dataframe: (8532073, 11) >>>
# [19:58:49] INFO: <<< Start saving dataframe with shape (113578, 28) >>>
# [19:58:51] INFO: <<< Saved processed file in directory C:\Users\sebis\OneDrive\Desktop\FOM\3. Semester\Big Data Analyseprojekt\battery_failure_predictions\data\Processed\Zyklus\processed_RW9.csv >>>

# %% [markdown]
# ## DFs zusammenführen

# %%
d = []

df_full = pd.DataFrame(d, columns=df_pv.columns)

for file in os.listdir(folder):
    if ".csv" in file:
        df = pd.read_csv(f"{folder}\\{file}")
        df_full = df_full.append(df)
df_full = df_full.reset_index()

# %% [markdown]
# # Variablenauswahl
# * **index** - kann raus
# * **batteryname_** - kann weg: keinen Einfluss
# * **zyklus_** - bleibt: Anzahl an Lade/Entlade/Pause Wechseln
# * **comment_** - kann weg: ist in time_entladen_*
# * **type_** - kann weg: ist in time_entladen_*
# * **current_amax** - kann weg: ist in Zielvariable/immer gleich
# * **current_amin** - kann weg: ist in Zielvariable/immer gleich
# * **current_mean** - kann weg: ist in Zielvariable/immer gleich
# * **relativeTime_amax** - kann weg: ist in Zielvariable
# * **temperature_amax** - bleibt: kann man mal ausprobieren, ob Temp Einfluss hat
# * **temperature_amin** - bleibt: kann man mal ausprobieren, ob Temp Einfluss hat
# * **temperature_mean** - bleibt: kann man mal ausprobieren, ob Temp Einfluss hat
# * **time_amin** - bleibt: Gesamtalter der Batterie bei Start
# * **voltage_amax** - kann weg: bei Ref Discharge immer von 4.2V zu 3.2V
# * **voltage_amin** - kann weg: bei Ref Discharge immer von 4.2V zu 3.2V
# * **voltage_mean** - kann weg: bei Ref Discharge immer von 4.2V zu 3.2V
# * **time_entladen_stark** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_entladen_leicht** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_laden_stark** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_laden_leicht** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_pause** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_entladen_stark_vorher** - bleibt: wie vorher verwendet
# * **time_entladen_leicht_vorher** - bleibt: wie vorher verwendet
# * **time_laden_stark_vorher** - bleibt: wie vorher verwendet
# * **time_laden_leicht_vorher** - bleibt: wie vorher verwendet
# * **time_pause_vorher** - bleibt: wie vorher verwendet
# * **time_temp_hoch** - kann weg: nur benötigt für "vorher"-Berechnung
# * **time_temp_hoch_vorher** - bleibt: wie vorher verwendet
# * **amperestunden** - bleibt: Zielvariable

# %%
var_auswahl = [
    "batteryname_",
    "amperestunden",
    "zyklus_",
    "comment_",
    "type_",
    "temperature_amax",
    "temperature_amin",
    "temperature_mean",
    "time_amin",
    "time_entladen_stark_vorher",
    "time_entladen_leicht_vorher",
    "time_laden_stark_vorher",
    "time_laden_leicht_vorher",
    "time_pause_vorher",
    "time_temp_hoch_vorher"
]

df_final = df_full[var_auswahl]
df_final.to_csv(f"{folder_final}\\df_fertige_features.csv", sep=',', index=False)

df_pv_filtered = df_final[df_final['comment_'] == 'reference discharge']
df_pv_filtered.to_csv(f"{folder_final}\\df_fertige_features_ref_discharge.csv", sep=',', index=False)

df_pv_filtered
# Out:
#         batteryname_  amperestunden zyklus_             comment_ type_  \
# 3                RW1       2.000364       3  reference discharge     D
# 5                RW1       2.000250       5  reference discharge     D
# 1009             RW1       1.958481    1009  reference discharge     D
# 1011             RW1       1.963192    1011  reference discharge     D
# 1925             RW1       1.911217    1925  reference discharge     D
# ...              ...            ...     ...                  ...   ...
# 1111856          RW9       0.784939  107540  reference discharge     D
# 1114867          RW9       0.759776  110551  reference discharge     D
# 1114871          RW9       0.758740  110555  reference discharge     D
# 1117888          RW9       0.748778  113572  reference discharge     D
# 1117892          RW9       0.750203  113576  reference discharge     D
#
#          temperature_amax  temperature_amin  temperature_mean    time_amin  \
# 3                23.56742          18.39025         21.798768    385232.92
# 5                24.06639          18.15403         21.449898    405533.19
# 1009             22.81896          17.57133         20.530506    839519.21
# 1011             23.64538          18.12253         21.420698    858525.62
# 1925             23.89487          17.66582         20.839432   1248403.47
# ...                   ...               ...               ...          ...
# 1111856          37.88939          31.96866         35.245658  12207354.10
# 1114867          37.79663          32.10779         35.343405  12427168.28
# 1114871          37.53384          31.59765         34.768506  12457189.16
# 1117888          38.29132          32.40151         35.719393  12672750.22
# 1117892          38.86329          32.46334         35.958514  12703478.83
#
#          time_entladen_stark_vorher  time_entladen_leicht_vorher  \
# 3                              0.00                    196178.50
# 5                              0.00                    203379.98
# 1009                       17749.62                    312669.57
# 1011                       17749.62                    319737.63
# 1925                       36155.14                    406768.88
# ...                             ...                          ...
# 1111856                   315859.21                   4021813.10
# 1114867                   317601.49                   4080113.57
# 1114871                   317601.49                   4082845.38
# 1117888                   319549.85                   4142731.52
# 1117892                   319549.85                   4145432.36
#
#         time_laden_stark_vorher  time_laden_leicht_vorher  time_pause_vorher  \
# 3                             0                 194718.28               0.00
# 5                             0                 207816.73               0.00
# 1009                          0                 472156.60           16048.39
# 1011                          0                 484111.86           16048.39
# 1925                          0                 743215.33           28472.48
# ...                         ...                       ...                ...
# 1111856               213165.35                4949765.16         1036683.27
# 1114867                213923.1                5040620.52         1059934.58
# 1114871                213923.1                5060405.85         1067434.58
# 1117888               214732.26                5144349.95         1094276.63
# 1117892               214732.26                5164882.66         1101776.63
#
#          time_temp_hoch_vorher
# 3                 0.000000e+00
# 5                 0.000000e+00
# 1009              1.784186e+05
# 1011              1.784186e+05
# 1925              3.443131e+05
# ...                        ...
# 1111856           9.016036e+06
# 1114867           9.190943e+06
# 1114871           9.220960e+06
# 1117888           9.394390e+06
# 1117892           9.425124e+06
#
# [950 rows x 15 columns]

# %% [markdown]
# ## Nachher:
# * Bei Temperatur scheint es Ausreißer in die -4000er Region zu geben, muss man noch ersetzen wenn man es benutzen will
