# %% [markdown]
# # Importing Data and defining functions for feature engineering
#
# 1. Import Modules
# 2. Import data
# 3. Defining of functions
# 4. Applying and testing

# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import numpy as np

import functions as fu
from feature_engineering import *

# Pfade setzen
c_fold = fu.get_folder()
p_fold = c_fold + '\data\Prepared'

# %% [markdown]
# # Importing Data

# %%
# import Full Data
#df = fu.csv_einlesen(p_fold)


# import one dataset for developing
df = pd.read_csv(f"{p_fold}\\prepared_RW20.csv", index_col = 0)
print("Size of Dataframe: ",df.shape)
# Out:
# Size of Dataframe:  (1222375, 11)

# %% [markdown]
# # Defining of Functions

# %% [markdown]
# # Applying and testing

# %%
df = feature_creator(df,['voltage','current','temperature'],['batteryname','zyklus'],"mean")
df = feature_creator(df,['voltage','current','temperature'],['batteryname','zyklus'],"median")
df = feature_creator(df,['voltage','current','temperature'],['batteryname','zyklus'],"min")
df = feature_creator(df,['voltage','current','temperature'],['batteryname','zyklus'],"max")
df = feature_creator(df,['voltage','current','temperature'],['batteryname','zyklus'],"std")
df = feature_creator(df,['voltage','current','temperature'],['batteryname','zyklus'],"count")
df.head()
# Out:
#   batteryname  zyklus  step                               comment type  \
# 0        RW20       0     0  charge (after random walk discharge)    C
# 1        RW20       0     1  charge (after random walk discharge)    C
# 2        RW20       0     2  charge (after random walk discharge)    C
# 3        RW20       0     3  charge (after random walk discharge)    C
# 4        RW20       0     4  charge (after random walk discharge)    C
#
#      time  relativeTime  voltage  current  temperature  ... min_voltage_all  \
# 0   60.04          0.04    3.957   -2.005     22.22000  ...           3.957
# 1  120.04         60.04    4.032   -2.000     22.26685  ...           3.957
# 2  180.04        120.04    4.051   -2.000     22.40741  ...           3.957
# 3  240.04        180.04    4.059   -2.000     22.61045  ...           3.957
# 4  300.04        240.04    4.064   -2.001     22.81348  ...           3.957
#
#    min_current_all  min_temperature_all  max_voltage_all  max_current_all  \
# 0           -2.005             21.79831              4.2            -0.01
# 1           -2.005             21.79831              4.2            -0.01
# 2           -2.005             21.79831              4.2            -0.01
# 3           -2.005             21.79831              4.2            -0.01
# 4           -2.005             21.79831              4.2            -0.01
#
#    max_temperature_all  std_voltage_all  std_current_all  std_temperature_all  \
# 0             26.04643         0.038696         0.728878             1.336022
# 1             26.04643         0.038696         0.728878             1.336022
# 2             26.04643         0.038696         0.728878             1.336022
# 3             26.04643         0.038696         0.728878             1.336022
# 4             26.04643         0.038696         0.728878             1.336022
#
#    count_entrys_all
# 0               167
# 1               167
# 2               167
# 3               167
# 4               167
#
# [5 rows x 27 columns]

# %%
df = feature_creator(df,'voltage',['batteryname','zyklus'],"std",'10')
# Out:
# Das hier ist nur ein dummy - das Framing muss noch ergänzt werden

# %%
df.sample(5)
# Out:
#         batteryname  zyklus  step                               comment type  \
# 886818         RW20   22583    50       rest post random walk discharge    R
# 1054671        RW20   25862    57  charge (after random walk discharge)    C
# 1171480        RW20   28077    43       rest post random walk discharge    R
# 567488         RW20   14918    37               discharge (random walk)    D
# 843515         RW20   21688   559               pulsed load (discharge)    D
#
#                 time  relativeTime  voltage  current  temperature  ...  \
# 886818    9070576.10       3000.01    4.101     0.00     21.10857  ...
# 1054671  12964685.85       3420.04    4.200    -0.02     18.25472  ...
# 1171480  15981063.89       2580.01    4.093     0.00     21.09306  ...
# 567488    4744051.74         37.04    3.413     3.50     37.87986  ...
# 843515    8289881.29        559.04    3.628     1.00     23.18564  ...
#
#         min_voltage_all  min_current_all  min_temperature_all  \
# 886818            3.618            0.000             21.07756
# 1054671           4.200           -0.833             17.87900
# 1171480           3.638            0.000             20.92256
# 567488            3.402            3.500             37.63428
# 843515            3.624            0.999             22.06960
#
#          max_voltage_all  max_current_all  max_temperature_all  \
# 886818             4.101            0.000             24.70470
# 1054671            4.219           -0.010             18.41127
# 1171480            4.095            0.000             23.77466
# 567488             3.461            3.504             38.04870
# 843515             3.778            1.004             23.23214
#
#          std_voltage_all  std_current_all  std_temperature_all  \
# 886818          0.062630         0.000000             1.119468
# 1054671         0.002138         0.109535             0.157170
# 1171480         0.059563         0.000000             0.842499
# 567488          0.014577         0.000526             0.125839
# 843515          0.031836         0.000376             0.355322
#
#          count_entrys_all
# 886818                 61
# 1054671                79
# 1171480                61
# 567488                 61
# 843515                601
#
# [5 rows x 27 columns]
